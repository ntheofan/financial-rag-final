# %% [markdown]
# # 11 — Error Analysis
#
# Αυτό το notebook αναλύει συστηματικά τα αποτελέσματα του pipeline για το **best run** (`hybrid_reranked`)
# και ταξινομεί κάθε ερώτηση σε **μία από τέσσερις κατηγορίες αποτυχίας** (ή σε επιτυχία).
#
# ## Taxonomy αποτυχιών
#
# | Κωδικός | Κατηγορία | Ορισμός |
# |---|---|---|
# | `SUCCESS` | Επιτυχία | Σωστό doc, η απάντηση περιέχει τη gold τιμή |
# | `RETRIEVAL_MISS` | Retrieval miss | Το σωστό doc **δεν** ανακτάται καθόλου στα top-K |
# | `WRONG_YEAR_DOC` | Λάθος έτος/doc | Σωστή εταιρεία, λάθος έτος ή τύπος αρχείου |
# | `GOOD_RETRIEVAL_BAD_ANSWER` | Generation failure | Σωστό doc ανακτάται, αλλά το LLM δεν απαντά σωστά |
# | `INSUFFICIENT_EVIDENCE` | Άρνηση απάντησης | Το LLM επέστρεψε 'Insufficient evidence...' |
#
# ## Σύνδεση με κεφάλαιο Αξιολόγησης
#
# Η ταξινόμηση αυτή αντιστοιχεί στη μεθοδολογία **failure mode analysis** που περιγράφεται στο
# Barnett et al. (2024) *Seven Failure Points When Engineering a RAG System*.
# Τα αποτελέσματα θα χρησιμοποιηθούν ως εμπειρικά ευρήματα στο κεφάλαιο Αξιολόγησης.

# %%
import json
import re
from pathlib import Path

import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Configuration

# %%
# ── Ποιο run να αναλύσουμε ──────────────────────────────────────────────────
PRIMARY_RUN = "hybrid_reranked"   # το best run σου
ALL_RUNS    = ["dense", "hybrid", "hybrid_reranked"]

# ── Threshold για το lexical F1 ώστε να θεωρείται "σωστή" η απάντηση ────────
# 0.5 = τουλάχιστον το μισό overlap με τη gold απάντηση
ANSWER_CORRECT_F1_THRESHOLD = 0.5

# ── Top-K που χρησιμοποιήθηκε στο retrieval ─────────────────────────────────
TOP_K = 10

# ── Paths (ίδιο σύστημα με τα υπόλοιπα notebooks) ───────────────────────────
CURRENT_DIR = Path.cwd()
BASE_DIR    = CURRENT_DIR.parent if CURRENT_DIR.name == "notebooks" else CURRENT_DIR

DATA_DIR      = BASE_DIR / "data"
INTERIM_DIR   = DATA_DIR / "interim"
PROCESSED_DIR = DATA_DIR / "processed"
QA_DIR        = PROCESSED_DIR / "qa_results"
RETRIEVAL_DIR = PROCESSED_DIR / "retrieval_results"
EVAL_DIR      = PROCESSED_DIR / "evaluation"
ERROR_DIR     = PROCESSED_DIR / "error_analysis"

ERROR_DIR.mkdir(parents=True, exist_ok=True)

WORKING_DATASET_PATH = (
    INTERIM_DIR / "financebench_open_source_working.parquet"
    if (INTERIM_DIR / "financebench_open_source_working.parquet").exists()
    else INTERIM_DIR / "financebench_open_source_working.csv"
)

print("BASE_DIR   :", BASE_DIR)
print("ERROR_DIR  :", ERROR_DIR)
print("PRIMARY_RUN:", PRIMARY_RUN)
# Out:
# BASE_DIR   : C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag
# ERROR_DIR  : C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag\data\processed\error_analysis
# PRIMARY_RUN: hybrid_reranked

# %% [markdown]
# ## 2. Φόρτωση δεδομένων

# %%
# ── Gold dataset ─────────────────────────────────────────────────────────────
if WORKING_DATASET_PATH.suffix == ".parquet":
    working_df = pd.read_parquet(WORKING_DATASET_PATH)
else:
    working_df = pd.read_csv(WORKING_DATASET_PATH)

print(f"working_df   : {working_df.shape}")

# ── QA results ───────────────────────────────────────────────────────────────
qa_dfs = {}
for run in ALL_RUNS:
    p = QA_DIR / f"rag_qa_results_{run}.csv"
    if p.exists():
        qa_dfs[run] = pd.read_csv(p)
        print(f"QA  {run:20s}: {qa_dfs[run].shape}")
    else:
        print(f"QA  {run:20s}: NOT FOUND — {p}")

# ── Retrieval results ─────────────────────────────────────────────────────────
retrieval_dfs = {}
for run in ALL_RUNS:
    p = RETRIEVAL_DIR / f"retrieval_results_{run}.parquet"
    if not p.exists():
        p = RETRIEVAL_DIR / f"retrieval_results_{run}.csv"
    if p.exists():
        retrieval_dfs[run] = pd.read_parquet(p) if p.suffix == ".parquet" else pd.read_csv(p)
        print(f"RET {run:20s}: {retrieval_dfs[run].shape}")
    else:
        print(f"RET {run:20s}: NOT FOUND")
# Out:
# working_df   : (150, 22)
# QA  dense               : (150, 13)
# QA  hybrid              : (150, 13)
# QA  hybrid_reranked     : (150, 13)
# RET dense               : (1500, 17)
# RET hybrid              : (1500, 21)
# RET hybrid_reranked     : (1500, 21)

# %% [markdown]
# ## 3. Βοηθητικές συναρτήσεις

# %%
# ── Normalization (ίδια λογική με notebook 12) ────────────────────────────────

def normalize_finance(text: str) -> str:
    """Ομαλοποίηση χρηματοοικονομικών τιμών για σύγκριση."""
    if pd.isna(text):
        return ""
    text = str(text).strip().lower()
    text = text.replace("$", "").replace(",", "")
    text = re.sub(r"\b(usd|million[s]?|billion[s]?)\b", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def tokenize(text: str) -> list:
    return re.findall(r"[a-z0-9\.\-\%]+", normalize_finance(text))


def lexical_f1(pred: str, gold: str) -> float:
    """Token-level F1 μεταξύ πρόβλεψης και gold απάντησης."""
    p_tok = tokenize(pred)
    g_tok = tokenize(gold)
    if not p_tok and not g_tok:
        return 1.0
    if not p_tok or not g_tok:
        return 0.0
    p_cnt = {t: p_tok.count(t) for t in set(p_tok)}
    g_cnt = {t: g_tok.count(t) for t in set(g_tok)}
    overlap = sum(min(c, g_cnt.get(t, 0)) for t, c in p_cnt.items())
    if overlap == 0:
        return 0.0
    prec = overlap / len(p_tok)
    rec  = overlap / len(g_tok)
    return 2 * prec * rec / (prec + rec)


def is_insufficient_evidence(text: str) -> bool:
    """Ελέγχει αν το LLM αρνήθηκε να απαντήσει."""
    if pd.isna(text):
        return True
    return "insufficient evidence" in str(text).lower()


def extract_company_from_doc(doc_name: str) -> str:
    """Εξάγει την εταιρεία από το doc_name (π.χ. '3M_2018_10K' → '3M')."""
    if pd.isna(doc_name):
        return ""
    parts = str(doc_name).split("_")
    return parts[0].upper() if parts else ""


print("Βοηθητικές συναρτήσεις φορτώθηκαν.")
# Out:
# Βοηθητικές συναρτήσεις φορτώθηκαν.

# %% [markdown]
# ## 4. Ταξινομητής αποτυχιών
#
# Η κεντρική συνάρτηση `classify_failure()` εφαρμόζει ένα **decision tree** ταξινόμησης:
# ελέγχει διαδοχικά (α) retrieval miss, (β) άρνηση απάντησης, (γ) λάθος έτος/doc, (δ) generation failure.

# %%
# Κατηγορίες αποτυχίας
FAILURE_CATEGORIES = [
    "SUCCESS",
    "RETRIEVAL_MISS",          # Το σωστό doc απουσιάζει εντελώς από τα top-K chunks
    "WRONG_YEAR_DOC",          # Σωστή εταιρεία, λάθος έτος ή τύπος εγγράφου
    "GOOD_RETRIEVAL_BAD_ANSWER",  # Σωστό doc ανακτάται, λάθος απάντηση από LLM
    "INSUFFICIENT_EVIDENCE",   # LLM αρνήθηκε να απαντήσει
]


def classify_failure(
    expected_doc: str,
    retrieved_docs: list,       # λίστα με τα doc_ids που ανακτήθηκαν (top-K)
    gold_answer: str,
    generated_answer: str,
    f1_threshold: float = ANSWER_CORRECT_F1_THRESHOLD,
) -> str:
    """
    Ταξινομεί κάθε ερώτηση σε μία κατηγορία αποτυχίας.

    Decision tree:
    1. Αν f1(generated, gold) >= threshold → SUCCESS
    2. Αν expected_doc δεν υπάρχει στα retrieved_docs → RETRIEVAL_MISS
    3. Αν LLM επέστρεψε 'Insufficient evidence' → INSUFFICIENT_EVIDENCE
    4. Αν expected_doc υπάρχει στα retrieved_docs (σωστή εταιρεία, λάθος f1)
       → GOOD_RETRIEVAL_BAD_ANSWER
    5. Αν η εταιρεία ταιριάζει αλλά το exact doc όχι → WRONG_YEAR_DOC
    6. Fallback → RETRIEVAL_MISS
    """
    f1 = lexical_f1(generated_answer, gold_answer)

    # Βήμα 1: Σωστή απάντηση
    if f1 >= f1_threshold:
        return "SUCCESS"

    expected_doc = str(expected_doc) if not pd.isna(expected_doc) else ""
    retrieved_set = {str(d) for d in retrieved_docs if not pd.isna(d)}

    # Βήμα 2: Retrieval miss — το σωστό doc απουσιάζει εντελώς
    doc_retrieved = expected_doc in retrieved_set

    # Βήμα 3: LLM αρνήθηκε (ακόμα και αν το doc ανακτήθηκε)
    if is_insufficient_evidence(generated_answer):
        if not doc_retrieved:
            return "RETRIEVAL_MISS"
        else:
            return "INSUFFICIENT_EVIDENCE"

    # Βήμα 4: Σωστό doc ανακτάται αλλά το LLM απαντά λάθος
    if doc_retrieved:
        return "GOOD_RETRIEVAL_BAD_ANSWER"

    # Βήμα 5: Σωστή εταιρεία, λάθος έτος/doc
    expected_company = extract_company_from_doc(expected_doc)
    retrieved_companies = {extract_company_from_doc(d) for d in retrieved_set}
    if expected_company and expected_company in retrieved_companies:
        return "WRONG_YEAR_DOC"

    # Βήμα 6: Fallback
    return "RETRIEVAL_MISS"


print("Ταξινομητής ορίστηκε.")
# Out:
# Ταξινομητής ορίστηκε.

# %% [markdown]
# ## 5. Εφαρμογή ταξινόμησης στο primary run

# %%
assert PRIMARY_RUN in qa_dfs, f"{PRIMARY_RUN} δεν βρέθηκε στα QA αποτελέσματα."
assert PRIMARY_RUN in retrieval_dfs, f"{PRIMARY_RUN} δεν βρέθηκε στα retrieval αποτελέσματα."

qa_df  = qa_dfs[PRIMARY_RUN].copy()
ret_df = retrieval_dfs[PRIMARY_RUN].copy()

# ── Χτίζουμε per-query λίστα retrieved doc_ids ──────────────────────────────
# Κρατάμε τα TOP_K ανακτηθέντα docs ανά ερώτηση
retrieved_docs_per_query = (
    ret_df[ret_df["retrieved_rank"] <= TOP_K]
    .groupby("financebench_id")["retrieved_doc_id"]
    .apply(list)
    .reset_index()
    .rename(columns={"retrieved_doc_id": "retrieved_doc_list"})
)

# ── Merge QA + retrieval ──────────────────────────────────────────────────────
analysis_df = qa_df.merge(retrieved_docs_per_query, on="financebench_id", how="left")
analysis_df["retrieved_doc_list"] = analysis_df["retrieved_doc_list"].apply(
    lambda x: x if isinstance(x, list) else []
)

# ── Εφαρμογή ταξινόμησης ─────────────────────────────────────────────────────
analysis_df["failure_category"] = analysis_df.apply(
    lambda row: classify_failure(
        expected_doc      = row.get("expected_doc_name", ""),
        retrieved_docs    = row["retrieved_doc_list"],
        gold_answer       = row.get("expected_answer", ""),
        generated_answer  = row.get("generated_answer", ""),
    ),
    axis=1,
)

# ── Lexical F1 per question ───────────────────────────────────────────────────
analysis_df["lexical_f1"] = analysis_df.apply(
    lambda row: lexical_f1(
        row.get("generated_answer", ""),
        row.get("expected_answer",  ""),
    ),
    axis=1,
)

print(f"analysis_df shape: {analysis_df.shape}")
print("\nΚατανομή κατηγοριών:")
print(analysis_df["failure_category"].value_counts())
# Out:
# analysis_df shape: (150, 16)
#
# Κατανομή κατηγοριών:
# failure_category
# GOOD_RETRIEVAL_BAD_ANSWER    63
# INSUFFICIENT_EVIDENCE        63
# RETRIEVAL_MISS               16
# SUCCESS                       7
# WRONG_YEAR_DOC                1
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Συνοπτική αναφορά

# %%
category_counts = analysis_df["failure_category"].value_counts()
total = len(analysis_df)

# ── Χτίζουμε το summary με το σωστό column name από την αρχή ─────────────────
summary_df = pd.DataFrame({
    "failure_category": category_counts.index,
    "count"           : category_counts.values,
    "percentage"      : (category_counts.values / total * 100).round(1),
})

# ── Μέσο F1 ανά κατηγορία (απευθείας merge, χωρίς conditional) ───────────────
mean_f1_df = (
    analysis_df
    .groupby("failure_category", as_index=False)["lexical_f1"]
    .mean()
    .rename(columns={"lexical_f1": "mean_f1"})
)
mean_f1_df["mean_f1"] = mean_f1_df["mean_f1"].round(3)

summary_df = summary_df.merge(mean_f1_df, on="failure_category", how="left")

print(f"\n{'='*60}")
print(f"  Error Analysis Summary — {PRIMARY_RUN} (N={total})")
print(f"{'='*60}")
print(summary_df.to_string(index=False))
print(f"{'='*60}\n")

summary_df
# Out:
# ============================================================
#   Error Analysis Summary — hybrid_reranked (N=150)
# ============================================================
#          failure_category  count  percentage  mean_f1
# GOOD_RETRIEVAL_BAD_ANSWER     63        42.0    0.192
#     INSUFFICIENT_EVIDENCE     63        42.0    0.039
#            RETRIEVAL_MISS     16        10.7    0.052
#                   SUCCESS      7         4.7    0.675
#            WRONG_YEAR_DOC      1         0.7    0.296
# ============================================================
#             failure_category  count  percentage  mean_f1
# 0  GOOD_RETRIEVAL_BAD_ANSWER     63        42.0    0.192
# 1      INSUFFICIENT_EVIDENCE     63        42.0    0.039
# 2             RETRIEVAL_MISS     16        10.7    0.052
# 3                    SUCCESS      7         4.7    0.675
# 4             WRONG_YEAR_DOC      1         0.7    0.296

# %% [markdown]
# ## 7. Ανάλυση ανά κατηγορία ερώτησης (question_type)
#
# Εξετάζουμε αν κάποιος τύπος ερώτησης (π.χ. `extractive`, `arithmetic`) παρουσιάζει
# συστηματικά υψηλότερα ποσοστά αποτυχίας — χρήσιμο για το ablation study.

# %%
# Merge με το working_df για να πάρουμε question_type, question_reasoning, gics_sector
meta_cols = ["financebench_id", "question_type", "question_reasoning", "gics_sector", "doc_type"]
available_meta = [c for c in meta_cols if c in working_df.columns]

rich_df = analysis_df.merge(
    working_df[available_meta].drop_duplicates(subset=["financebench_id"]),
    on="financebench_id",
    how="left",
)

# ── Αποτυχίες ανά question_type ──────────────────────────────────────────────
if "question_type" in rich_df.columns:
    print("\n── Αποτυχίες ανά question_type ──")
    qt_pivot = pd.crosstab(
        rich_df["question_type"],
        rich_df["failure_category"],
        margins=True,
        margins_name="TOTAL",
    )
    print(qt_pivot)

# ── Αποτυχίες ανά doc_type (10K vs 10Q) ─────────────────────────────────────
if "doc_type" in rich_df.columns:
    print("\n── Αποτυχίες ανά doc_type ──")
    dt_pivot = pd.crosstab(
        rich_df["doc_type"],
        rich_df["failure_category"],
        margins=True,
        margins_name="TOTAL",
    )
    print(dt_pivot)
# Out:
# ── Αποτυχίες ανά question_type ──
# failure_category   GOOD_RETRIEVAL_BAD_ANSWER  INSUFFICIENT_EVIDENCE  \
# question_type
# domain-relevant                           18                     19
# metrics-generated                         15                     27
# novel-generated                           30                     17
# TOTAL                                     63                     63
#
# failure_category   RETRIEVAL_MISS  SUCCESS  WRONG_YEAR_DOC  TOTAL
# question_type
# domain-relevant                 7        5               1     50
# metrics-generated               8        0               0     50
# novel-generated                 1        2               0     50
# TOTAL                          16        7               1    150
#
# ── Αποτυχίες ανά doc_type ──
# failure_category  GOOD_RETRIEVAL_BAD_ANSWER  INSUFFICIENT_EVIDENCE  \
# doc_type
# 10k                                      39                     52
# 10q                                       7                      8
# 8k                                        8                      0
# Earnings                                  9                      3
# TOTAL                                    63                     63
#
# failure_category  RETRIEVAL_MISS  SUCCESS  WRONG_YEAR_DOC  TOTAL
# doc_type
# 10k                           15        5               1    112
# 10q                            0        0               0     15
# 8k                             0        1               0      9
# Earnings                       1        1               0     14
# TOTAL                         16        7               1    150

# %% [markdown]
# ## 8. Qualitative examples ανά κατηγορία
#
# Για κάθε κατηγορία αποτυχίας, εμφανίζουμε **3 αντιπροσωπευτικά παραδείγματα**
# για ποιοτική ανάλυση (θα ενσωματωθούν στο κεφάλαιο Ευρημάτων).

# %%
display_cols = [
    "financebench_id",
    "question",
    "expected_answer",
    "generated_answer",
    "expected_doc_name",
    "retrieved_doc_list",
    "lexical_f1",
    "failure_category",
]
display_cols = [c for c in display_cols if c in rich_df.columns]

for category in FAILURE_CATEGORIES:
    subset = rich_df[rich_df["failure_category"] == category]
    if len(subset) == 0:
        continue

    print(f"\n{'─'*70}")
    print(f"  {category}  (N={len(subset)})")
    print(f"{'─'*70}")

    examples = subset.sample(min(3, len(subset)), random_state=42)
    for _, row in examples.iterrows():
        print(f"\n  ID      : {row.get('financebench_id', '')}")
        q = str(row.get('question', ''))[:120]
        print(f"  Question: {q}..." if len(str(row.get('question',''))) > 120 else f"  Question: {q}")
        print(f"  Gold    : {str(row.get('expected_answer', ''))[:100]}")
        print(f"  Pred    : {str(row.get('generated_answer', ''))[:100]}")
        print(f"  F1      : {row.get('lexical_f1', 0):.3f}")
        print(f"  Exp.doc : {row.get('expected_doc_name', '')}")
        retrieved = row.get('retrieved_doc_list', [])
        if isinstance(retrieved, list):
            print(f"  Ret.docs: {retrieved[:5]}")
# Out:
# ──────────────────────────────────────────────────────────────────────
#   SUCCESS  (N=7)
# ──────────────────────────────────────────────────────────────────────
#
#   ID      : financebench_id_01319
#   Question: What is the quantity of restructuring costs directly outlined in AES Corporation's income statements for FY2022? If rest...
#   Gold    : 0
#   Pred    : $0
#   F1      : 1.000
#   Exp.doc : AES_2022_10K
#   Ret.docs: ['AES_2022_10K', 'GENERALMILLS_2022_10K', 'AES_2022_10K', 'AES_2022_10K', '3M_2022_10K']
#
#   ID      : financebench_id_00995
#   Question: What are the major products and services that AMD sells as of FY22?
#   Gold    : AMD sells server microprocessors (CPUs) and graphics processing units (GPUs), data processing units
#   Pred    : As of FY22, AMD's products include x86 microprocessors (CPUs), graphics processing units (GPUs), acc
#   F1      : 0.614
#   Exp.doc : AMD_2022_10K
#   Ret.docs: ['AMD_2022_10K', 'AMD_2022_10K', 'AMD_2022_10K', 'AMD_2015_10K', 'AMD_2015_10K']
#
#   ID      : financebench_id_01254
#   Question: Has MGM Resorts paid dividends to common shareholders in FY2022?
#   Gold    : Yes. MGM maintained 0.01$ per share annual dividend through out FY 2022.
#   Pred    : Yes, the company maintained an annual dividend of $0.01 per share throughout 2022.
#   F1      : 0.560
#   Exp.doc : MGMRESORTS_2022_10K
#   Ret.docs: ['MGMRESORTS_2022Q4_EARNINGS', 'MGMRESORTS_2018_10K', 'MGMRESORTS_2018_10K', 'MGMRESORTS_2022_10K', 'MGMRESORTS_2020_10K']
#
# ──────────────────────────────────────────────────────────────────────
#   RETRIEVAL_MISS  (N=16)
# ──────────────────────────────────────────────────────────────────────
#
#   ID      : financebench_id_04735
#   Question: You are an investment banker and your only resource(s) to answer the following question is (are): the statement of finan...
#   Gold    : 0.66
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.000
#   Exp.doc : ADOBE_2015_10K
#   Ret.docs: ['AMAZON_2017_10K', 'AMERICANWATERWORKS_2020_10K', 'VERIZON_2021_10K', 'VERIZON_2022_10K', 'AMAZON_2017_10K']
#
#   ID      : financebench_id_03856
#   Question: What is the FY2017 operating cash flow ratio for Adobe? Operating cash flow ratio is defined as: cash from operations / ...
#   Gold    : 0.83
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.000
#   Exp.doc : ADOBE_2017_10K
#   Ret.docs: ['WALMART_2018_10K', 'AMAZON_2017_10K', 'WALMART_2018_10K', 'WALMART_2019_10K', 'NETFLIX_2017_10K']
#
#   ID      : financebench_id_04660
#   Question: Considering the data in the balance sheet, what is Block's (formerly known as Square) FY2016 working capital ratio? Defi...
#   Gold    : 1.73
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.000
#   Exp.doc : BLOCK_2016_10K
#   Ret.docs: ['BESTBUY_2017_10K', '3M_2022_10K', '3M_2023Q2_10Q', 'JPMORGAN_2021Q1_10Q', 'WALMART_2018_10K']
#
# ──────────────────────────────────────────────────────────────────────
#   WRONG_YEAR_DOC  (N=1)
# ──────────────────────────────────────────────────────────────────────
#
#   ID      : financebench_id_00685
#   Question: Are Best Buy's gross margins historically consistent (not fluctuating more than roughly 2% each year)? If gross margins ...
#   Gold    : Yes, the margins have been consistent, there has been a minor decline of 1.1% in gross margins betwe
#   Pred    : Best Buy's gross margins were consistent between the two years provided, increasing from 23.3% in 20
#   F1      : 0.296
#   Exp.doc : BESTBUY_2023_10K
#   Ret.docs: ['BESTBUY_2017_10K', 'BESTBUY_2017_10K', 'BESTBUY_2024Q2_10Q', 'COCACOLA_2021_10K', 'COCACOLA_2022_10K']
#
# ──────────────────────────────────────────────────────────────────────
#   GOOD_RETRIEVAL_BAD_ANSWER  (N=63)
# ──────────────────────────────────────────────────────────────────────
#
#   ID      : financebench_id_04784
#   Question: Based on the information provided primarily in the statement of income, what is the FY2018 - FY2019 change in unadjusted...
#   Gold    : 0.2%
#   Pred    : 0.2%
# ($21,957M / $510,329M) - ($20,437M / $495,761M) = 0.2%
#   F1      : 0.250
#   Exp.doc : WALMART_2019_10K
#   Ret.docs: ['WALMART_2019_10K', 'WALMART_2020_10K', 'WALMART_2018_10K', 'WALMART_2019_10K', 'WALMART_2020_10K']
#
#   ID      : financebench_id_00601
#   Question: What drove the reduction in SG&A expense as a percent of net sales in FY2023?
#   Gold    : Lower marketing expenses and leverage of incentive compensation due to higher sales. The answer here
#   Pred    : The decrease in SG&A expenses in fiscal year 2023 was primarily driven by exchange rate movements, w
#   F1      : 0.182
#   Exp.doc : ULTABEAUTY_2023Q4_EARNINGS
#   Ret.docs: ['AMCOR_2023_10K', 'COSTCO_2021_10K', 'BESTBUY_2023_10K', 'ULTABEAUTY_2023_10K', 'ULTABEAUTY_2023Q4_EARNINGS']
#
#   ID      : financebench_id_03029
#   Question: What is the FY2018 capital expenditure amount (in USD millions) for 3M? Give a response to the question by relying on th...
#   Gold    : $1577.00
#   Pred    : $1,577M
#   F1      : 0.000
#   Exp.doc : 3M_2018_10K
#   Ret.docs: ['3M_2018_10K', 'COCACOLA_2017_10K', '3M_2018_10K', '3M_2022_10K', '3M_2023Q2_10Q']
#
# ──────────────────────────────────────────────────────────────────────
#   INSUFFICIENT_EVIDENCE  (N=63)
# ──────────────────────────────────────────────────────────────────────
#
#   ID      : financebench_id_00215
#   Question: Is Verizon a capital intensive business based on FY 2022 data?
#   Gold    : Yes. Verizon's capital intensity ratio was approximately 2.774729. This means that it took approxima
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.000
#   Exp.doc : VERIZON_2022_10K
#   Ret.docs: ['VERIZON_2022_10K', 'VERIZON_2022_10K', 'VERIZON_2022_10K', 'VERIZON_2021_10K', 'VERIZON_2022_10K']
#
#   ID      : financebench_id_00605
#   Question: What percent of Ulta Beauty's total spend on stock repurchases for FY 2023 occurred in Q4 of FY2023?
#   Gold    : 36%. The answer here assumes FY2023 refers to the 12 months ended on January 28, 2023 (although the
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.061
#   Exp.doc : ULTABEAUTY_2023Q4_EARNINGS
#   Ret.docs: ['ULTABEAUTY_2023Q4_EARNINGS', 'ULTABEAUTY_2023Q4_EARNINGS', 'ULTABEAUTY_2023_10K', 'ULTABEAUTY_2023_10K', 'ULTABEAUTY_2023Q4_EARNINGS']
#
#   ID      : financebench_id_01865
#   Question: If we exclude the impact of M&A, which segment has dragged down 3M's overall growth in 2022?
#   Gold    : The consumer segment shrunk by 0.9% organically.
#   Pred    : Insufficient evidence in the retrieved context.
#   F1      : 0.154
#   Exp.doc : 3M_2022_10K
#   Ret.docs: ['3M_2022_10K', '3M_2023Q2_10Q', '3M_2023Q2_10Q', '3M_2022_10K', '3M_2022_10K']

# %% [markdown]
# ## 9. Σύγκριση αποτυχιών μεταξύ όλων των runs
#
# Εξετάζουμε πώς εξελίσσεται η κατανομή κατηγοριών καθώς βελτιώνουμε το pipeline:
# `dense` → `hybrid` → `hybrid_reranked`.

# %%
cross_run_rows = []

for run in ALL_RUNS:
    if run not in qa_dfs or run not in retrieval_dfs:
        print(f"Παράλειψη {run}: λείπουν δεδομένα")
        continue

    _qa  = qa_dfs[run].copy()
    _ret = retrieval_dfs[run].copy()

    _ret_docs = (
        _ret[_ret["retrieved_rank"] <= TOP_K]
        .groupby("financebench_id")["retrieved_doc_id"]
        .apply(list)
        .reset_index()
        .rename(columns={"retrieved_doc_id": "retrieved_doc_list"})
    )

    _df = _qa.merge(_ret_docs, on="financebench_id", how="left")
    _df["retrieved_doc_list"] = _df["retrieved_doc_list"].apply(
        lambda x: x if isinstance(x, list) else []
    )

    _df["failure_category"] = _df.apply(
        lambda row: classify_failure(
            expected_doc     = row.get("expected_doc_name", ""),
            retrieved_docs   = row["retrieved_doc_list"],
            gold_answer      = row.get("expected_answer", ""),
            generated_answer = row.get("generated_answer", ""),
        ),
        axis=1,
    )

    for cat, cnt in _df["failure_category"].value_counts().items():
        cross_run_rows.append({
            "run"             : run,
            "failure_category": cat,
            "count"           : int(cnt),
            "percentage"      : round(cnt / len(_df) * 100, 1),
        })

cross_run_df = pd.DataFrame(cross_run_rows)

# Pivot για ευκολότερη ανάγνωση
pivot = cross_run_df.pivot_table(
    index="failure_category",
    columns="run",
    values="percentage",
    aggfunc="first",
).fillna(0)

# Επαναδιατύπωση στη σειρά dense → hybrid → hybrid_reranked
ordered_runs = [r for r in ALL_RUNS if r in pivot.columns]
pivot = pivot[ordered_runs]

print("\nΠοσοστά (%) ανά κατηγορία και run:")
print(pivot.to_string())
# Out:
# Ποσοστά (%) ανά κατηγορία και run:
# run                        dense  hybrid  hybrid_reranked
# failure_category
# GOOD_RETRIEVAL_BAD_ANSWER   36.7    33.3             42.0
# INSUFFICIENT_EVIDENCE       48.0    50.7             42.0
# RETRIEVAL_MISS              11.3    11.3             10.7
# SUCCESS                      4.0     4.7              4.7
# WRONG_YEAR_DOC               0.0     0.0              0.7

# %% [markdown]
# ## 10. Αποθήκευση αποτελεσμάτων

# %%
# ── Full analysis table ───────────────────────────────────────────────────────
save_cols = [
    "financebench_id", "question", "expected_answer", "generated_answer",
    "expected_doc_name", "top_doc_id", "lexical_f1", "failure_category",
]
save_cols = [c for c in save_cols if c in rich_df.columns]

out_full = ERROR_DIR / f"error_analysis_{PRIMARY_RUN}.csv"
rich_df[save_cols].to_csv(out_full, index=False)
print(f"Αποθηκεύτηκε: {out_full}")

# ── Summary ────────────────────────────────────────────────────────────────────
out_summary = ERROR_DIR / f"error_summary_{PRIMARY_RUN}.csv"
summary_df.to_csv(out_summary, index=False)
print(f"Αποθηκεύτηκε: {out_summary}")

# ── Cross-run comparison ───────────────────────────────────────────────────────
out_cross = ERROR_DIR / "error_cross_run_comparison.csv"
cross_run_df.to_csv(out_cross, index=False)
print(f"Αποθηκεύτηκε: {out_cross}")

# ── JSON stats (για εύκολη αναφορά στη διπλωματική) ──────────────────────────
stats = {
    "run"            : PRIMARY_RUN,
    "total_queries"  : int(total),
    "f1_threshold"   : ANSWER_CORRECT_F1_THRESHOLD,
    "top_k"          : TOP_K,
    "category_counts": {
        row["failure_category"]: {
            "count"     : int(row["count"]),
            "percentage": float(row["percentage"]),
        }
        for _, row in summary_df.iterrows()
    },
}

out_json = ERROR_DIR / f"error_stats_{PRIMARY_RUN}.json"
with open(out_json, "w", encoding="utf-8") as f:
    json.dump(stats, f, indent=2, ensure_ascii=False)
print(f"Αποθηκεύτηκε: {out_json}")

print("\n✓ Error analysis ολοκληρώθηκε.")
# Out:
# Αποθηκεύτηκε: C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag\data\processed\error_analysis\error_analysis_hybrid_reranked.csv
# Αποθηκεύτηκε: C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag\data\processed\error_analysis\error_summary_hybrid_reranked.csv
# Αποθηκεύτηκε: C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag\data\processed\error_analysis\error_cross_run_comparison.csv
# Αποθηκεύτηκε: C:\Users\ntheo\Desktop\Repositories\Financial-RAG\thesis-rag\data\processed\error_analysis\error_stats_hybrid_reranked.json
#
# ✓ Error analysis ολοκληρώθηκε.

# %% [markdown]
# ---
#
# ## Σημειώσεις για τη Διπλωματική
#
# ### Πώς να αναφέρεις αυτά τα αποτελέσματα
#
# Στο κεφάλαιο **Αξιολόγηση / Ανάλυση Σφαλμάτων**, μπορείς να αναφερθείς ως εξής:
#
# > *«Προκειμένου να αποσαφηνιστεί η κατανομή των αποτυχιών του συστήματος, εφαρμόστηκε
# > ταξινόμηση αποτυχιών σε τέσσερις κατηγορίες, εμπνευσμένη από τη μεθοδολογία
# > των Barnett et al. (2024). Η ανάλυση αποκαλύπτει ότι το μεγαλύτερο ποσοστό αποτυχιών
# > εντοπίζεται στην κατηγορία [X], γεγονός που τεκμαίρει ότι [retrieval/generation]
# > αποτελεί τον κρίσιμο παράγοντα βελτίωσης του συστήματος.»*
#
# ### Βιβλιογραφική σύνδεση
#
# - **Barnett et al. (2024)** — *Seven Failure Points When Engineering a RAG System*
#   → Θεωρητική βάση για την taxonomy αποτυχιών
# - **Rackauckas (2024)** — *Decomposing Retrieval Failures in RAG for Long Documents*
#   → Αναλυτικότερη κατηγοριοποίηση retrieval αποτυχιών
# - **FinanceBench (Laban et al., 2023)**
#   → Το benchmark που χρησιμοποιείται ορίζει `question_type` και `question_reasoning`
#     τα οποία αξιοποιούνται στο Section 7 αυτού του notebook
